# %%
# Layout and Positioning
''' Question 1: What are semantic HTML elements? Why are they important?
                Semantic HTML elements are tags that carry meaning about the content they enclose. Examples: <header>, <article>, <section>, <footer>, <nav>.

                Importance:
                  Improves accessibility (screen readers understand structure better).
                  Enhances SEO (search engines know what’s important).
                  Makes code more readable and maintainable.
                  Provides better default styling and behavior in browsers.


Question 2: Structuring a blog page with semantic elements
            For a blog page, you might use:
            <header> → Blog title, navigation.
            <nav> → Links to categories or other pages.
            <main> → Main content area.
            <article> → Each blog post.
            <section> → Grouping related posts or content.
            <aside> → Sidebar with ads, related links, or author bio.
            <footer> → Copyright, contact info, social links.
            This structure makes the page logical and accessible.

Question 3: Making an HTML form accessible
            Use <label> linked to inputs via for and id.
            Provide clear instructions and error messages.
            Use semantic input types (email, tel, date) for better device support.
            Ensure keyboard navigation works (tab order).
            Add aria-label or aria-describedby for screen readers when needed.
            Maintain good color contrast for text and backgrounds.

Question 4: Identify and correct the errors in the following CSS code:
p {
 font-size: 16;
 color: #333
 margin-top 10px;
}

answer:      p {
                font-size: 16px;
                color: #333;
                margin-top: 10px;
              }
              Fixes:
              Added px unit to font-size.
              Added missing semicolons.
              Added colon after margin-top.

Question 5: CSS rules for <h2> inside <section>
 answer:    section h2 {
                  color: blue;
                  text-align: center;
              }

Question 6: CSS Box Model
answer:     The box model describes how every element is treated as a rectangular box:
              Content → Text or images inside the element.
              Padding → Space between content and border.
              Border → Surrounds padding and content.
              Margin → Space outside the border, separating elements.
              So total element size = content + padding + border + margin.

Question 7: Positioning in CSS
answer:     Relative → Positioned relative to its normal place. Other elements don’t move.
            Absolute → Positioned relative to the nearest positioned ancestor (not the viewport unless no ancestor is positioned).
            Fixed → Positioned relative to the viewport. Stays in place even when scrolling.
'''
# Out:
# ' Question 1: What are semantic HTML elements? Why are they important?\n                Semantic HTML elements are tags that carry meaning about the content they enclose. Examples: <header>, <article>, <section>, <footer>, <nav>.\n\n                Importance:\n                  Improves accessibility (screen readers understand structure better).\n                  Enhances SEO (search engines know what’s important).\n                  Makes code more readable and maintainable.\n                  Provides better default styling and behavior in browsers.\n\n\nQuestion 2: Structuring a blog page with semantic elements\n            For a blog page, you might use:\n            <header> → Blog title, navigation.\n            <nav> → Links to categories or other pages.\n            <main> → Main content area.\n            <article> → Each blog post.\n            <section> → Grouping related posts or content.\n            <aside> → Sidebar with ads, related links, or author bio.\n          
# ...
