# %%
''' Question 1 : Create a layout with three boxes side by side using Flexbox. The first box
should have twice the width of the other two. Provide the HTML and CSS code
snippets.
answer : html
        <div class="flex-container">
          <div class="box box1">Box 1</div>
          <div class="box box2">Box 2</div>
          <div class="box box3">Box 3</div>
        </div>

        style.css
        .flex-container {
          display: flex;
        }

        .box {
          background: lightcoral;
          margin: 5px;
          text-align: center;
          padding: 20px;
        }

        .box1 {
          flex: 2; /* Twice the width */
        }

        .box2, .box3 {
          flex: 1;
        }


Question 2: Using CSS Grid, create a 2x2 grid layout where the first row spans two
columns, and the second row has two equal columns. Provide the HTML and CSS code
snippets.
answer:   <div class="grid-container">
            <div class="item item1">Row 1 spans 2 columns</div>
            <div class="item item2">Row 2, Column 1</div>
            <div class="item item3">Row 2, Column 2</div>
          </div>

          css
          .grid-container {
              display: grid;
              grid-template-columns: 1fr 1fr;
              grid-template-rows: auto auto;
              gap: 10px;
            }

            .item1 {
              grid-column: span 2;
              background: lightblue;
            }

            .item2, .item3 {
              background: lightgreen;
            }




Question 3: Write a media query that changes the background color of the body to light
grey when the screen width is less than 600px.
answer: @media (max-width: 600px) {
            body {
              background-color: lightgrey;
            }
          }



Question 4: Create a button that changes its background color to blue and scales up
slightly when hovered over, using CSS transitions. Provide the HTML and CSS code
snippets.
answer:  <button class="hover-btn">Hover Me</button>

         css
        .hover-btn {
          background: lightcoral;
          padding: 10px 20px;
          border: none;
          cursor: pointer;
          transition: all 0.3s ease;
        }

        .hover-btn:hover {
          background: blue;
          transform: scale(1.1);
        }


Question 5: Use the ::before pseudo-element to add a decorative icon before each list
item in an unordered list with the class name ‘decorated-list’. Provide the HTML and
CSS code snippets.
answer:    <ul class="decorated-list">
            <li>Item One</li>
            <li>Item Two</li>
            <li>Item Three</li>
          </ul>

          css
          .decorated-list li::before {
            content: "★ "; /* Decorative icon */
            color: orange;
          }



Question 6: Create a simple animation that moves a square box from left to right
infinitely. Provide the HTML and CSS code snippets.
answer:     <div class="moving-box"></div>

            css
            .moving-box {
              width: 50px;
              height: 50px;
              background: red;
              position: relative;
              animation: moveRight 3s linear infinite;
            }

            @keyframes moveRight {
              from { left: 0; }
              to { left: 100%; }
            }


Question 7: Explain the difference between position: absolute; and position: fixed;
in CSS.
answer:     position: absolute;
            Positions the element relative to its nearest positioned ancestor (not static).
            If no ancestor is positioned, it uses the document body.
            Moves with the page when scrolling.

            position: fixed;
            Positions the element relative to the viewport (browser window).
            Stays in place even when the page is scrolled.
            Commonly used for sticky headers, navigation bars, or floating buttons.
'''
# Out:
# ' Question 1 : Create a layout with three boxes side by side using Flexbox. The first box\nshould have twice the width of the other two. Provide the HTML and CSS code\nsnippets.\nanswer : html\n        <div class="flex-container">\n          <div class="box box1">Box 1</div>\n          <div class="box box2">Box 2</div>\n          <div class="box box3">Box 3</div>\n        </div>\n\n        style.css\n        .flex-container {\n          display: flex;\n        }\n\n        .box {\n          background: lightcoral;\n          margin: 5px;\n          text-align: center;\n          padding: 20px;\n        }\n\n        .box1 {\n          flex: 2; /* Twice the width */\n        }\n\n        .box2, .box3 {\n          flex: 1;\n        }\n\n\nQuestion 2: Using CSS Grid, create a 2x2 grid layout where the first row spans two\ncolumns, and the second row has two equal columns. Provide the HTML and CSS code\nsnippets.\nanswer:   <div class="grid-container">\n            <div class="item item1">Row 1 spans 2 columns</div>\n            <div class="item item2">Row 2, Column 1</div>\n            <div class="item item3">Row 2, Column 2</div>\n          </div>\n\n          css\n          .grid-container {\n              display: grid;\n              grid-template-columns: 1fr 1fr;\n              grid-template-rows: auto auto;\n              gap: 10px;\n            }\n\n            .item1 {\n              grid-column: span 2;\n              background: lightblue;\n            }\n\n            .item2, .item3 {\n              background: lightgreen;\n            }\n\n   \n\n\nQuestion 3: Write a media query that changes the background color of the body to light\ngrey when the screen width is less than 600px.\nanswer: @media (max-width: 600px) {\n            body {\n              background-color: lightgrey;\n            }\n          }\n\n\n\nQuestion 4: Create a button that changes its background color to blue and scales up\nslightly when hovered over, using CSS transitions. Provide the HTML and CSS code\nsnippets.\nanswer:  <button class="hover-btn">Hover Me</button>\n\n         css\n        .hover-btn {\n          background: lightcoral;\n          padding: 10px 20px;\n          border: none;\n          cursor: pointer;\n          transition: all 0.3s ease;\n        }\n\n        .hover-btn:hover {\n          background: blue;\n          transform: scale(1.1);\n        }\n\n\nQuestion 5: Use the ::before pseudo-element to add a decorative icon before each list\nitem in an unordered list with the class name ‘decorated-list’. Provide the HTML and\nCSS code snippets.\nanswer:    <ul class="decorated-list">\n            <li>Item One</li>\n            <li>Item Two</li>\n            <li>Item Three</li>\n          </ul>\n\n          css\n          .decorated-list li::before {\n            content: "★ "; /* Decorative icon */\n            color: orange;\n          }\n\n\n\nQuestion 6: Create a simple animation that moves a square box from left to right\ninfinitely. Provide the HTML and CSS code snippets.\nanswer:     <div class="moving-box"></div>\n\n            css\n            .moving-box {\n              width: 50px;\n              height: 50px;\n              background: red;\n              position: relative;\n              animation: moveRight 3s linear infinite;\n            }\n\n            @keyframes moveRight {\n              from { left: 0; }\n              to { left: 100%; }\n            }\n\n\nQuestion 7: Explain the difference between position: absolute; and position: fixed;\nin CSS.\nanswer:     position: absolute;\n            Positions the element relative to its nearest positioned ancestor (not static).\n            If no ancestor is positioned, it uses the document body.\n            Moves with the page when scrolling.\n\n            position: fixed;\n            Positions the element relative to the viewport (browser window).\n            Stays in place even when the page is scrolled.\n            Commonly used for sticky headers, n ...
